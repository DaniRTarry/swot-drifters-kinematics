# %% [markdown]
# http://localhost:8888/notebooks/FaSt-SWOT/Drifters/SOCIB_drifters_thredds_ALL_Chl_230508_allDrifters.ipynb

# %%
#venv py3_parcels_DIAG
import numpy as np
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LongitudeFormatter, LatitudeFormatter
import xarray as xr
import cmocean
import datetime
import json
import matplotlib.colors as colors

# %% [markdown]
# # 1. Loading the data:

# %% [markdown]
# ## Drifters

# %% [markdown]
# https://www.socib.es/?seccion=observingFacilities&facility=lagrangianPlatforms

# %%
url_root = "http://thredds.socib.es/thredds/dodsC/drifter/surface_drifter/"

# %% [markdown]
# ### HEREON:

# %%
url_vars_her = "trajectory,time[0:1:-1],LAT[0:1:-1],QC_LAT[0:1:-1],LON[0:1:-1],QC_LON[0:1:-1],DEPTH,PLAT_SPEED_GR[0:1:-1],QC_PLAT_SPEED_GR[0:1:-1],PLAT_COURSE[0:1:-1],QC_PLAT_COURSE[0:1:-1],BAT_STATUS[0:1:-1]"

# %%
# https://thredds.socib.es/thredds/catalog/drifter/surface_drifter/drifter_hereon011-ime_hereon011/L1/2023/catalog.html?dataset=drifter/surface_drifter/drifter_hereon011-ime_hereon011/L1/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc

# opendap
## clicking on opendap link:
# https://thredds.socib.es/thredds/dodsC/drifter/surface_drifter/drifter_hereon011-ime_hereon011/L1/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc.html
# putting -1 as index instead to have the last data point:
url_01 = url_root + "drifter_hereon011-ime_hereon011/L1/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc?" + url_vars_her

ds_her011 = xr.open_dataset(url_01)

# %%
mm = '4'.zfill(2)

#10: 28/04
drifter_num = '10'.zfill(3)
dd = '28'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her010 = xr.open_dataset(url_01)

#09: 27/04
drifter_num = '9'.zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her009 = xr.open_dataset(url_01)

#08: 27/04
drifter_num = '8'.zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her008 = xr.open_dataset(url_01)

#07: 27/04
drifter_num = '7'.zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her007 = xr.open_dataset(url_01)

#06: 27/04
drifter_num = '6'.zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her006 = xr.open_dataset(url_01)

#04: 27/04
drifter_num = '4'.zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her004 = xr.open_dataset(url_01)

#03: 26/04
drifter_num = '3'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her003 = xr.open_dataset(url_01)

#02: 26/04
drifter_num = '2'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her002 = xr.open_dataset(url_01)

#01: 26/04
drifter_num = '1'.zfill(3)
dd = '26'.zfill(2)
# attention! prev trial done, so here dep0001_ is dep0002_
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0002_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her001 = xr.open_dataset(url_01)

# %%
ds_her_leg1 = [ds_her001, ds_her002, ds_her003
                        ,ds_her004, ds_her006, ds_her007, ds_her008
                        ,ds_her009, ds_her010, ds_her011]

# %%
mm = '5'.zfill(2)

#05: 08/05
drifter_num = '5'.zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her005 = xr.open_dataset(url_01)

#12: 08/05
drifter_num = '12'.zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her012 = xr.open_dataset(url_01)

#13: 08/05
drifter_num = '13'.zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her013 = xr.open_dataset(url_01)

#14: 08/05
drifter_num = '14'.zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her014 = xr.open_dataset(url_01)

#####

#15: 10/05
drifter_num = '15'.zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her015 = xr.open_dataset(url_01)

#16: 10/05
drifter_num = '16'.zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her016 = xr.open_dataset(url_01)

#17: 10/05
drifter_num = '17'.zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her017 = xr.open_dataset(url_01)

#18: 10/05
drifter_num = '18'.zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her018 = xr.open_dataset(url_01)

# #19: 10/05
# drifter_num = '19'.zfill(3)
# dd = '10'.zfill(2)
# url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
# ds_her019 = xr.open_dataset(url_01)
url_02 = 'http://thredds.socib.es/thredds/dodsC/drifter/surface_drifter/drifter_hereon019-ime_hereon019/L1/2023/dep0001_drifter-hereon019_ime-hereon019_L1_2023-05-10.nc?trajectory,time[0:1:314],LAT[0:1:314],QC_LAT[0:1:314],LON[0:1:314],QC_LON[0:1:314],DEPTH,PLAT_SPEED_GR[0:1:314],QC_PLAT_SPEED_GR[0:1:314],PLAT_COURSE[0:1:314],QC_PLAT_COURSE[0:1:314],BAT_STATUS[0:1:314]'
ds_her019 = xr.open_dataset(url_02)

#20: 10/05
drifter_num = '20'.zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_her
ds_her020 = xr.open_dataset(url_01)

# %%
ds_her_leg2 = [ds_her005, ds_her011, ds_her012, ds_her013, ds_her014
              , ds_her015, ds_her016, ds_her017, ds_her018, ds_her019, ds_her020]

# %% [markdown]
# ### CARTHE

# %%
url_vars_car = "trajectory,time[0:1:-1],LAT[0:1:-1],QC_LAT[0:1:-1],LON[0:1:-1],QC_LON[0:1:-1],DEPTH,PLAT_SPEED_GR[0:1:-1],QC_PLAT_SPEED_GR[0:1:-1],BAT_STATUS[0:1:-1]"
# CARTHE no course, but HEREON yes dunno why

# %%
url_01 = url_root + "drifter_carthe015-ime_carthe010/L1/2023/dep0001_drifter-carthe015_ime-carthe010_L1_2023-04-28.nc?" + url_vars_car
ds_car010 = xr.open_dataset(url_01)

# %%
mm = '4'.zfill(2)

#8: 27/04
drifter_num = '8'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car008 = xr.open_dataset(url_01)

#07: 27/04
drifter_num = '7'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car007 = xr.open_dataset(url_01)

#06: 27/04
drifter_num = '6'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car006 = xr.open_dataset(url_01)

#05: 27/04
drifter_num = '5'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car005 = xr.open_dataset(url_01)

#04: 27/04
drifter_num = '4'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '27'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car004 = xr.open_dataset(url_01)

#03: 26/04
drifter_num = '3'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car003 = xr.open_dataset(url_01)

#02: 26/04
drifter_num = '2'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car002 = xr.open_dataset(url_01)

#01: 26/04
drifter_num = '1'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '26'.zfill(2)
# attention! prev trial done, so here dep0001_ is dep0002_
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0002_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car001 = xr.open_dataset(url_01)

#09: 24/04
drifter_num = '9'.zfill(3)
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '28'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car009 = xr.open_dataset(url_01)

# %%
ds_car_leg1 = [ds_car001, ds_car002, ds_car003
                        ,ds_car004, ds_car005, ds_car006, ds_car007 ,ds_car008
                        ,ds_car009, ds_car010]

# %%
mm = '5'.zfill(2)

#11: 08/05
drifter_num = '11'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car011 = xr.open_dataset(url_01)
# https://thredds.socib.es/thredds/catalog/drifter/surface_drifter/drifter_carthe016-ime_carthe011/L1/2023/catalog.html

#12: 08/05
drifter_num = '12'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car012 = xr.open_dataset(url_01)

#13: 08/05
drifter_num = '13'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '8'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car013 = xr.open_dataset(url_01)

#14: 09/05
drifter_num = '14'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '9'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car014 = xr.open_dataset(url_01)

#15: 10/05
drifter_num = '15'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car015 = xr.open_dataset(url_01)

#16: 10/05
drifter_num = '16'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car016 = xr.open_dataset(url_01)

#17: 10/05
drifter_num = '17'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car017 = xr.open_dataset(url_01)

#18: 10/05
drifter_num = '18'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car018 = xr.open_dataset(url_01)

#19: 10/05
drifter_num = '19'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car019 = xr.open_dataset(url_01)

#20: 10/05
drifter_num = '20'.zfill(3)
# for some reason to id numbers..
drifter_num2 = str(int(drifter_num) + 5).zfill(3)
dd = '10'.zfill(2)
url_01 = url_root + "drifter_carthe" + drifter_num2 + "-ime_carthe" + drifter_num + "/L1/2023/dep0001_drifter-carthe" + drifter_num2 + "_ime-carthe" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_car
ds_car020 = xr.open_dataset(url_01)

# %%
ds_car_leg2 = [ds_car011, ds_car012, ds_car013
                        ,ds_car014, ds_car015, ds_car016, ds_car017, ds_car018
                        ,ds_car019, ds_car020]

# %% [markdown]
# ### SVP-B

# %%
url_vars_svp = "trajectory,time[0:1:-1],LAT[0:1:-1],QC_LAT[0:1:-1],LON[0:1:-1],QC_LON[0:1:-1],DEPTH,PSPEED[0:1:-1],QC_PSPEED[0:1:-1],APRE[0:1:-1],QC_APRE[0:1:-1],WTEM[0:1:-1],QC_WTEM[0:1:-1]"

# %%
mm = '4'.zfill(2)

#42: 26/04
drifter_num = '42'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_svpb" + drifter_num + "-scb_svpb" + drifter_num + "/L1/2023/dep0001_drifter-svpb" + drifter_num + "_scb-svpb" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_svp
ds_svp042 = xr.open_dataset(url_01)

#41: 26/04
drifter_num = '41'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_svpb" + drifter_num + "-scb_svpb" + drifter_num + "/L1/2023/dep0001_drifter-svpb" + drifter_num + "_scb-svpb" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_svp
ds_svp041 = xr.open_dataset(url_01)

#40: 26/04
drifter_num = '40'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_svpb" + drifter_num + "-scb_svpb" + drifter_num + "/L1/2023/dep0001_drifter-svpb" + drifter_num + "_scb-svpb" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_svp
ds_svp040 = xr.open_dataset(url_01)

#39: 26/04
drifter_num = '39'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_svpb" + drifter_num + "-scb_svpb" + drifter_num + "/L1/2023/dep0001_drifter-svpb" + drifter_num + "_scb-svpb" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_svp
ds_svp039 = xr.open_dataset(url_01)

#38: 26/04
drifter_num = '38'.zfill(3)
dd = '26'.zfill(2)
url_01 = url_root + "drifter_svpb" + drifter_num + "-scb_svpb" + drifter_num + "/L1/2023/dep0001_drifter-svpb" + drifter_num + "_scb-svpb" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" + url_vars_svp
ds_svp038 = xr.open_dataset(url_01)

# %% [markdown]
# ### THE SVP-B drifter of Leg 1 (previous to launch), the cool one in the eddy:
# <br>
# Surface drifter SCB-SVPB035 (wmo 6102812)
# <br>
#
# http://apps.socib.es/dapp/?deployments=2142-30-0

# %%
url_01 = url_root + "drifter_svpb035-scb_svpb035/L1/2023/dep0001_drifter-svpb035_scb-svpb035_L1_2023-02-20.nc?" + url_vars_svp
ds_svp035 = xr.open_dataset(url_01)

# %%
ds_svp_leg1 = [ds_svp035, ds_svp038, ds_svp039
                        ,ds_svp040, ds_svp041, ds_svp042]

# %% [markdown]
# ## Daily satellite field (Dani plot).  Chlorphyll here:

# %%
filedir = '/Users/Gomez023/Downloads/'

# %%
ds_chl_230506 = xr.open_dataset(filedir + 'oc-med-chl-multi-l3-chl_1km_daily-rt_20230506_FaSt-SWOT.nc')
ds_chl_230508 = xr.open_dataset(filedir + 'oc-med-chl-multi-l3-chl_1km_daily-rt_20230508_FaSt-SWOT.nc')

# %%
### Set date
year = 2023
month = 5
day = 4

### Set map extent
pW = ds_chl_230506.lon.min() #0.8
pE = 2.3
pS = 39.4
pN = ds_chl_230506.lat.max() #40.6
xticks = np.arange(0,4,0.2)
yticks = np.arange(38,41,0.1)
extent = [pW,pE,pS,pN]

labelsz = 12
fontsz  = 14
s = 10
lw = 0.5


### Read satellite data
fname = '%d%02d%02d000000-GOS-L3S_GHRSST-SSTsubskin-night_SST_UHR_NRT-MED-v02.0-fv01.0.nc' %(year,month,day)
if day==26:
    fname = 'SST_MED_SST_L3S_NRT_OBSERVATIONS_010_012_b_1682544781503.nc'

# %%
def plot_field_params(axn, nxticks, nyticks, nextent):
    #ax.set_aspect(1/np.cos(np.deg2rad(np.mean([pN,pS]))))

    # ax.add_feature(
    #     cfeature.GSHHSFeature(
    #     scale='h',
    #     facecolor='silver',
    #     linewidth=0.5)
    #     )

    # Axis format
    #     axn.set_xticks(nxticks, crs=ccrs.PlateCarree())
    #     axn.set_yticks(nyticks, crs=ccrs.PlateCarree())
    axn.set_extent(nextent, ccrs.PlateCarree())
    #     axn.tick_params(
    #         axis='x', 
    #         which='both', 
    #         bottom=True, 
    #         top=False, 
    #         labelbottom=True, 
    #         labelsize=labelsz
    #         )
    #ax.set_xlabel('Longitude', fontsize=labelsz)
    #     axn.tick_params(
    #         axis='y', 
    #         which='both', 
    #         left=True, 
    #         right=False, 
    #         labelleft=True, 
    #         labelsize=labelsz
    #    )
    #     #ax.set_ylabel('Latitude', fontsize=fontsz)
    #     lon_formatter = LongitudeFormatter(zero_direction_label=True)
    #     lat_formatter = LatitudeFormatter()
    #     axn.xaxis.set_major_formatter(lon_formatter)
    #     axn.yaxis.set_major_formatter(lat_formatter)
    
    # Grid and ticks
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                      linewidth=0.8, color='gray', linestyle='-') #, alpha=0.5

    gl.top_labels = False
    gl.right_labels = False
    
    gl.xlabel_style = {'size': fontsz-1}#, 'color': 'gray'}
    gl.ylabel_style = {'size': fontsz-1}#, 'color': 'gray'}

# %%
transect = np.load('/Users/Gomez023/Postdoc/develop/FaSt-SWOT/FaSt-SWOT2_transect.npz')
#http://localhost:8888/notebooks/FaSt-SWOT/FaST-SWOT2_SST_map_radiator_grid_MVP_CTD_and_gliders_along_swath_edited.ipynb
lon_south=transect['lon_south']
lon_north=transect['lon_north']
lat_south=transect['lat_south']
lat_north=transect['lat_north']

# lon_north=lon_east, lat_south=lat_west, lat_north=lat_east

# %% [markdown]
# ## Plotting Chlorphyll:

# %%
plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(16,10))
ax = plt.subplot(121, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230506.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.09 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto'
    )

########
####

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    ticks=np.linspace(vmin,vmax,6),
    format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

plt.title('20230506 Chl.', size=16)

###########
###########
ax = plt.subplot(122, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.12 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto'
    )

########

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    ticks=np.linspace(vmin,vmax,6),
    format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

plt.title('20230508 Chl.', size=16)
# Out:
# Text(0.5, 1.0, '20230508 Chl.')

# %% [markdown]
# ### Log scale:

# %%
plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(16,10))
ax = plt.subplot(121, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230506.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.09 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto',
    norm=colors.LogNorm(vmin=field.min(), vmax=field.max()),
    )

########
####

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    #ticks=np.linspace(vmin,vmax,6),
    #format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

plt.title('20230506 Chl.', size=16)

###########
###########
ax = plt.subplot(122, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.12 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto',
    norm=colors.LogNorm(vmin=field.min(), vmax=field.max()),
    )
########

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    #ticks=np.linspace(vmin,vmax,6),
    #format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

plt.title('20230508 Chl.', size=16)
# Out:
# Text(0.5, 1.0, '20230508 Chl.')

# %% [markdown]
# # Plots Chl. with all the drifters:

# %% [markdown]
# ## Chl. 08/05:

# %% [markdown]
# ### Drifters 10-12:

# %%
dd1 = '6'
dd2 = '10'

plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(111, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.11 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto'
    )

########
####

# plot (lon_south, lat_south) and (lon_north, lat_north)
ax.plot(lon_south, lat_south, 'o',color='g', markersize=10, transform=ccrs.PlateCarree())    
ax.plot(lon_north, lat_north, '*', color='g', markersize=10, transform=ccrs.PlateCarree())    

    
# plot lines joining points    
for ii in np.arange(lon_south.shape[0]):
    ax.plot([lon_south[ii], lon_north[ii]], [lat_south[ii], lat_north[ii]], color='g', zorder=10,
                transform=ccrs.PlateCarree())
    
    if ii in np.arange(0, lon_south.shape[0]-2, 2):
        ax.plot([lon_north[ii], lon_north[ii+1]], [lat_north[ii], lat_north[ii+1]], color='g', zorder=10,
                    transform=ccrs.PlateCarree())        
        
    if ii in np.arange(1, lon_south.shape[0], 2):
        ax.plot([lon_south[ii], lon_south[ii+1]], [lat_south[ii], lat_south[ii+1]], color='g', zorder=10,
                    transform=ccrs.PlateCarree())              

########
###### Drifters
# Hereon drifters:
for ii, ds in enumerate(ds_her_leg1): 
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    #     ds_day1 = ds.sel(time=ds.time[ds.time.dt.day == 6])
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='b') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='b', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='b', label='HEREON1') 

for ii, ds in enumerate(ds_car_leg1):
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    #print(ds_last2.time.shape)
    if ds_last2.time.shape[0] == 0 :
        #print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='k') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='k', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='k', label='CARTHE1') 

for ds in ds_her_leg2:
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='c', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c', label='HEREON2') 

for ds in ds_car_leg2:
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    if ds_last2.time.shape[0] == 0 :
        print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='grey', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey', label='CARTHE2') 

for ii, ds in enumerate(ds_svp_leg1):
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='r') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='r', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='r', label='SVP-B')
#######

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    ticks=np.linspace(vmin,vmax,6),
    format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

ax.legend()
plt.title('20230508 Chl. + drifters 06-10/05', size=16)

# fig.savefig('FaSt-SWOT2_MVP_radiator_grid_90deg_coords_Chl20230508_drifters_1012.png', 
#             dpi=400)
# Out:
# Text(0.5, 1.0, '20230508 Chl. + drifters 06-10/05')

# %% [markdown]
# ### Log-scale Chl and without radiator grid:

# %%
extent = [pW,pE,pS,pN]
print([pW,pE,pS,pN])
# Out:
# [<xarray.DataArray 'lon' ()>
# array(1.0212364, dtype=float32), 2.3, 39.4, <xarray.DataArray 'lat' ()>
# array(40.516457, dtype=float32)]

# %%
# extent = [pW, pE, 39.5, 40.7] # no chl data farther north

# %%
# Drifter trajectory days
dd1 = '05' #ini
dd2 = '10' #end

plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.11 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto',
    norm=colors.LogNorm(vmin=field.min(), vmax=field.max())
    )

########

###### Drifters
# Hereon drifters:
for ii, ds in enumerate(ds_her_leg1): 
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    #     ds_day1 = ds.sel(time=ds.time[ds.time.dt.day == 6])
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='b') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='b', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='b', label='HEREON1') 

for ii, ds in enumerate(ds_car_leg1):
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    #print(ds_last2.time.shape)
    if ds_last2.time.shape[0] == 0 :
        #print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='k') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='k', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='k', label='CARTHE1') 

for ds in ds_her_leg2:
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='c', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c', label='HEREON2') 

for ds in ds_car_leg2:
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    if ds_last2.time.shape[0] == 0 :
        print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='grey', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey', label='CARTHE2') 

for ii, ds in enumerate(ds_svp_leg1):
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='r') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='r', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='r', label='SVP-B')
#######

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    #ticks=np.linspace(vmin,vmax,6),
    #format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

ax.legend(loc="lower right")
plt.title('Chl. 08/05/23 + drifters 05-10/05/23', size=16)
plt.tight_layout()

fig.savefig('FaSt-SWOT2_Chl20230508log_drifters_all_0510.png', 
            dpi=400, bbox_inches='tight')

# %% [markdown]
# # Only leg 2 drifters:

# %%
extent = [1.2, 2., 39.45, 40.] # no chl data farther north

# %%
# Drifter trajectory days
dd1 = '05' #ini
dd2 = '10' #end

plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(111, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.08 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto',
    norm=colors.LogNorm(vmin=field.min(), vmax=field.max())
    )

########

###### Drifters
for ds in ds_her_leg2:
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='c', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c', label='HEREON2') 

for ds in ds_car_leg2:
    ds_last2 = ds.sel(time=slice('2023-05-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    if ds_last2.time.shape[0] == 0 :
        print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='grey', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey', label='CARTHE2') 

#######

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    #ticks=np.linspace(vmin,vmax,6),
    #format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

ax.legend(loc="lower right")
plt.title('20230508 Chl. + Leg 2 drifters 05-10/05', size=16)

# fig.savefig('FaSt-SWOT2_MVP_radiator_grid_90deg_coords_Chl20230508_drifters_1012.png', 
#             dpi=400)
# Out:
# Text(0.5, 1.0, '20230508 Chl. + Leg 2 drifters 05-10/05')

# %% [markdown]
# # Tail from deployment:

# %%
# Drifter trajectory days
dd1 = '05' #ini
# (if deployment day is later gives no error, just selects from start of file)
dd2 = '10' #end

plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(111, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.08 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto',
    norm=colors.LogNorm(vmin=field.min(), vmax=field.max())
    )

########

###### Drifters
for ds in ds_her_leg2:
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    print(dd1,mm1)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='c', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c', label='HEREON2') 

for ds in ds_car_leg2:
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    if ds_last2.time.shape[0] == 0 :
        print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='grey', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey', label='CARTHE2') 

#######

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    #ticks=np.linspace(vmin,vmax,6),
    #format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

ax.legend(loc="lower right")
plt.title('20230508 Chl. + Leg 2 drifters deployment-10/05', size=16)

# fig.savefig('FaSt-SWOT2_MVP_radiator_grid_90deg_coords_Chl20230508_drifters_1012.png', 
#             dpi=400)
# Out:
# 08 05
# 28 04
# 08 05
# 08 05
# 08 05
# 10 05
# 10 05
# 10 05
# 10 05
# 10 05
# 10 05
# Text(0.5, 1.0, '20230508 Chl. + Leg 2 drifters deployment-10/05')

# %% [markdown]
# # --> problem with hereon start date 28/04!

# %% [markdown]
# ### All drifters:

# %%
extent = [pW,pE,pS,pN]

# %%
# Drifter trajectory days
dd1 = '05' #ini
dd2 = '10' #end

plt.close()
plt.cla
plt.clf

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(111, projection=ccrs.PlateCarree())

plot_field_params(ax, xticks, yticks, extent)

field = ds_chl_230508.CHL.squeeze()
cmap = cmocean.cm.algae
cbar_label = r'Chl. ($mg/m^3$)'
vmin = 0.05 #np.nanpercentile(field, 5) #np.percentile(field[np.isfinite(field)],5)
vmax = 0.11 #np.nanpercentile(field, 95) #np.percentile(field[np.isfinite(field)],95)
cs = ax.pcolormesh(
    ds_chl_230506.lon , ds_chl_230506.lat, field,
    cmap=cmap,
    vmin=vmin,
    vmax=vmax,
    transform=ccrs.PlateCarree(),
    shading='auto',
    norm=colors.LogNorm(vmin=field.min(), vmax=field.max())
    )

########

###### Drifters
# Hereon drifters:
for ii, ds in enumerate(ds_her_leg1): 
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    #     ds_day1 = ds.sel(time=ds.time[ds.time.dt.day == 6])
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='b') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='b', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='b', label='HEREON1') 

for ii, ds in enumerate(ds_car_leg1):
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    if ds_last2.time.shape[0] == 0 :
        #print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='k') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='k', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='k', label='CARTHE1') 

for ds in ds_her_leg2:
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='c', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='c', label='HEREON2') 

for ds in ds_car_leg2:
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    if ds_last2.time.shape[0] == 0 :
        print('No drifter data')
        continue
    else:
        ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey') 
        ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='grey', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='grey', label='CARTHE2') 

for ii, ds in enumerate(ds_svp_leg1):
    dd1 = str(ds.time.dt.day.values[0]).zfill(2)
    mm1 = str(ds.time.dt.month.values[0]).zfill(2)
    ds_last2 = ds.sel(time=slice('2023-' + mm1 + '-' + dd1 + 'T00:00:00', '2023-05-' + dd2 + 'T23:59:59'))
    ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='r') 
    ax.scatter(ds_last2.LON[-1], ds_last2.LAT[-1], c='r', edgecolor='w', linewidths=0.8, transform=ccrs.PlateCarree())
ax.plot(ds_last2.LON, ds_last2.LAT, transform=ccrs.PlateCarree(), c='r', label='SVP-B')
#######

cbar = fig.colorbar(
    cs,
    orientation='vertical', 
    extend='both',
    shrink=0.6,
    #ticks=np.linspace(vmin,vmax,6),
    #format='%3.2f'
    )
cbar.ax.tick_params(labelsize=labelsz)
cbar.ax.set_ylabel(cbar_label, fontsize=fontsz)

ax.legend(loc="lower right")
plt.title('20230508 Chl. + drifters deployment-10/05', size=16)

# fig.savefig('FaSt-SWOT2_MVP_radiator_grid_90deg_coords_Chl20230508_drifters_1012.png', 
#             dpi=400)
# Out:
# Text(0.5, 1.0, '20230508 Chl. + drifters deployment-10/05')
