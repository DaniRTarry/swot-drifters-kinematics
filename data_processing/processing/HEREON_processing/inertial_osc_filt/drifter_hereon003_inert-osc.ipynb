# %% [markdown]
# Author(s) : Elisabet Verger-Miralles and Laura Gómez Navarro
#
# Objective: Describe xxx
#
# Created on: May 2024
#
# Last updated on:

# %%
import time

print(time.ctime(time.time()))
# Out:
# Sun Jun 16 21:14:26 2024

# %%
import sys
sys.path.insert(0, "../../../processing/")

# %%
import numpy as np
import xarray as xr # version 0.20.1 necesarry, 0.16 gives error when calculating u_for
import matplotlib.pyplot as plt
import scipy.signal as signal
from scipy.signal import butter, filtfilt

import cartopy
import cartopy.crs as ccrs
import cartopy.feature       as cfeature
from cartopy.mpl.gridliner import LongitudeFormatter, LatitudeFormatter

from read_data_tools import latlon2uv_dir

# %%
# version_information

# %%
print(xr.__version__)
# Out:
# 2023.6.0

# %% [markdown]
# # Parameters:

# %%
savedir_figs = '../../proc_figures/'

# %% [markdown]
# # 1. Loading data

# %% [markdown]
# (processed here: /Users/Gomez023/src/git/FaSt-SWOT/code/data_processing/drifters/processing/SVPB_processing/)

# %%
# !ls ../../../../../../data/drifters/L1_IMEDEA/*her*
# Out:
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon001-ime_hereon001.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon002-ime_hereon002.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon003-ime_hereon003.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon004-ime_hereon004.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon005-ime_hereon005.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon006-ime_hereon006.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon007-ime_hereon007.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon008-ime_hereon008.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon009-ime_hereon009.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon010-ime_hereon010.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon011-ime_hereon011.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon012-ime_hereon012.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon013-ime_hereon013.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon014-ime_hereon014.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon015-ime_hereon015.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon016-ime_hereon016.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon017-ime_hereon017.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon018-ime_hereon018.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon019-ime_hereon019.nc
# ../../../../../../data/drifters/L1_IMEDEA/drifter_hereon020-ime_hereon020.nc

# %%
# url_drifter = "drifter_svpb040-scb_svpb040/L0/2023/dep0001_drifter-svpb040_scb-svpb040_L0_2023-04-26.nc?"

rootdir = '../../../../../../'
outdir = 'data/drifters/L1_IMEDEA/'

# outname = url_drifter.split('/')[-1][0:-1].replace('L0', 'L1').replace('scb', 'ime') #outname
# --> substitute L0 by L1 and scb by ime. [0:-1], because last character in string is ?
# outname = outname.split('_')[1]
drifter_num=3
outname = 'drifter_hereon003-ime_hereon003'

# %% [markdown]
# ## Opening netcdf:

# %%
ds = xr.open_dataset(rootdir + outdir + outname + '.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 6569)
# Coordinates:
#     DEPTH          float64 ...
#   * time           (time) datetime64[ns] 2023-04-26T20:40:00 ... 2023-06-11T1...
# Data variables:
#     LAT            (time) float64 ...
#     LON            (time) float64 ...
#     PLAT_SPEED_GR  (time) float64 ...
#     PLAT_COURSE    (time) float64 ...
#     BAT_STATUS     (time) float64 ...
#     U              (time) float64 ...
#     V              (time) float64 ...
# Attributes: (12/67)
#     title:                               Data from instrument IME-HEREON003 o...
#     institution:                         IMEDEA (Instituto MEDiterráneo de Es...
#     netcdf_version:                      3.0
#     Conventions:                         CF-1.6
#     abstract:                            Deployment of IME-HEREON003 in FaSt-...
#     summary:                             Deployment of IME-HEREON003 in FaSt-...
#     ...                                  ...
#     citation:                            Balearic Island Coastal and Observin...
#     acknowledgement:                     The FaSt-SWOT project is funded by t...
#     update_interval:                     every 3600 seconds
#     DODS.strlen:                         34
#     DODS.dimName:                        name_strlen
#     DODS_EXTRA.Unlimited_Dimension:      time

# %% [markdown]
# # 2. Plotting outputs

# %%
map_extent=[-0.3, 7.9, 37.9, 41.5]
fsize=14

# %%
fig = plt.figure(figsize=(14,8))

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())


#############
# Land
feature = cartopy.feature.NaturalEarthFeature(name='coastline', category='physical',
                                              scale='10m', zorder=10,
                                              edgecolor='black', facecolor='#AAAAAA')
ax1.add_feature(feature)
#############
# Grid and ticks
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=0.5, color='gray', linestyle='-') #, alpha=0.5

gl.top_labels = False
gl.right_labels = False

gl.xlabel_style = {'size': fsize}#, 'color': 'gray'}
gl.ylabel_style = {'size': fsize}#, 'color': 'gray'}
#############

ax1.plot(ds.LON, ds.LAT, transform=ccrs.PlateCarree(), c='C0') 
ax1.scatter(ds.LON[0], ds.LAT[0], c='C3', edgecolor='k', linewidths=0.8, transform=ccrs.PlateCarree(), label='Start', zorder=50)

ax1.set_extent(map_extent, crs=ccrs.PlateCarree())
ax1.legend()
# ax1.set_title('Trajectory of ' + ds.attrs['title'].split(' ')[3].split('-')[-1], size=fsize+2) 

# outname = url_drifter.split('/')[-1][0:-1].replace('L0', 'L1').replace('scb', 'ime') #outname
# --> substitute L0 by L1 and scb by ime. [0:-1], because last character in string is ?
# outname = outname.split('_')[1]

# plt.savefig(savedir_figs + 'traj_proc_' + outname + '.png', dpi=300)

plt.show()

# %% [markdown]
# ## Velocity:

# %%
thresa = .1
map_extent_zoom = [ds.LON.min().values - thresa, ds.LON.max().values + thresa, ds.LAT.min().values - thresa, ds.LAT.max().values + thresa]

# %%
abs_vel = (ds.U**2 + ds.V**2)**0.5

# %%
fig = plt.figure(figsize=(14,8))

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())


#############
# Land
feature = cartopy.feature.NaturalEarthFeature(name='coastline', category='physical',
                                              scale='10m', zorder=10,
                                              edgecolor='black', facecolor='#AAAAAA')
ax1.add_feature(feature)
#############
# Grid and ticks
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=0.5, color='gray', linestyle='-') #, alpha=0.5

gl.top_labels = False
gl.right_labels = False

gl.xlabel_style = {'size': fsize}#, 'color': 'gray'}
gl.ylabel_style = {'size': fsize}#, 'color': 'gray'}
#############

cc = ax1.scatter(ds.LON, ds.LAT, s=5, c=abs_vel, transform=ccrs.PlateCarree())
ax1.scatter(ds.LON[0], ds.LAT[0], c='C3', edgecolor='k', linewidths=0.8, transform=ccrs.PlateCarree()
            , label='Start')
cbar = plt.colorbar(cc)
cbar_label = r'Absolute velocity (m/s)'
cbar.ax.tick_params(labelsize=fsize-2)
cbar.ax.set_ylabel(cbar_label, fontsize=fsize)

ax1.set_extent(map_extent_zoom, crs=ccrs.PlateCarree())
ax1.legend()
# ax1.set_title(ds05.attrs['title'].split(' ')[3].split('-')[-1], size=fsize+2) 

# outname = url_drifter.split('/')[-1][0:-1].replace('L0', 'L1').replace('scb', 'ime') #outname
# # --> substitute L0 by L1 and scb by ime. [0:-1], because last character in string is ?
# outname = outname.split('_')[1]

plt.savefig(savedir_figs + 'traj_proc_vels_' + outname + '.png', dpi=300)

plt.show()

# %% [markdown]
# # Filtering inertial osc.:

# %%
def butter_highpass_filter(data, cutoff, fs, order=5):
    """
    Aplica un filtro Butterworth de paso alto.
   
        Args:
        - data: Array de datos a filtrar.
        - cutoff: Frecuencia de corte del filtro.
        - fs: Frecuencia de muestreo de los datos.
        - order: Orden del filtro.
    
        Returns:
        - y: Datos filtrados.
    
    """
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 6569)>
# array(['2023-04-26T20:40:00.000000000', '2023-04-26T20:50:00.000000000',
#        '2023-04-26T21:00:00.000000000', ..., '2023-06-11T11:00:00.000000000',
#        '2023-06-11T11:10:00.000000000', '2023-06-11T11:20:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     DEPTH    float64 ...
#   * time     (time) datetime64[ns] 2023-04-26T20:40:00 ... 2023-06-11T11:20:00
# Attributes:
#     standard_name:  time
#     axis:           T

# %%
cuttof_frequency = 1/36. # 31 hores
fs = 6. # mostreig cada 10 mins en comptes de 1h!

# %%
# --> double check params!

# %%
lon_filtered = butter_highpass_filter(ds.LON, cuttof_frequency, fs)
lat_filtered = butter_highpass_filter(ds.LAT, cuttof_frequency, fs)

# %%
plt.figure()
plt.plot(ds.LON, c='b')
plt.plot(lon_filtered, c='r')
plt.grid()
plt.show()

# %% [markdown]
# # --> looks good!

# %% [markdown]
# ## New dataset:

# %%
ds_f = ds.copy(deep=True)

# %%
ds_f['LON'][:] = lon_filtered
ds_f['LAT'][:] = lat_filtered

# %% [markdown]
# # Replotting in space:

# %%
fig = plt.figure(figsize=(14,8))

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())


#############
# Land
feature = cartopy.feature.NaturalEarthFeature(name='coastline', category='physical',
                                              scale='10m', zorder=10,
                                              edgecolor='black', facecolor='#AAAAAA')
ax1.add_feature(feature)
#############
# Grid and ticks
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=0.5, color='gray', linestyle='-') #, alpha=0.5

gl.top_labels = False
gl.right_labels = False

gl.xlabel_style = {'size': fsize}#, 'color': 'gray'}
gl.ylabel_style = {'size': fsize}#, 'color': 'gray'}
#############

ax1.plot(ds.LON, ds.LAT, transform=ccrs.PlateCarree(), c='C0', label='Proc.') 
ax1.scatter(ds.LON[0], ds.LAT[0], c='C3', edgecolor='k', linewidths=0.8, transform=ccrs.PlateCarree(), label='Start', zorder=50)
ax1.plot(ds_f.LON, ds_f.LAT, transform=ccrs.PlateCarree(), c='C3', label='Proc. + filtered') 

ax1.set_extent(map_extent_zoom, crs=ccrs.PlateCarree())
ax1.legend()
# ax1.set_title('Trajectory of ' + ds.attrs['title'].split(' ')[3].split('-')[-1], size=fsize+2) 

# plt.savefig(savedir_figs + 'traj_proc_' + outname + '.png', dpi=300)

plt.show()

# %% [markdown]
# # --> ok

# %% [markdown]
# # Recalculating U and V:

# %%
temp_res = 3600. # 1 hour in seconds (double-check this value still ok here)

# %%
speed, ufor, vfor = latlon2uv_dir(ds_f.LAT, ds_f.LON, temp_res, 'forward')
_, uback, vback = latlon2uv_dir(ds_f.LAT, ds_f.LON, temp_res, 'back')

# %%
# Calculate central value
u = (ufor + uback) / 2
v = (vfor + vback) / 2

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.plot(ds.U, c='b')
plt.plot(u, c='r')
plt.title('U [m/s]')
plt.grid()

plt.subplot(1,2,2)
plt.plot(ds.V, c='b', label='processed')
plt.plot(v, c='r', label='proc. + inert. osc. filter')
plt.grid()
plt.title('V [m/s]')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# ## Assigning new U and V values:

# %%
ds_f['U'][:] = u
ds_f['V'][:] = v

# %% [markdown]
# # Saving:

# %%
ds_f
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 6569)
# Coordinates:
#     DEPTH          float64 ...
#   * time           (time) datetime64[ns] 2023-04-26T20:40:00 ... 2023-06-11T1...
# Data variables:
#     LAT            (time) float64 39.81 39.81 39.81 39.81 ... 41.2 41.2 41.2
#     LON            (time) float64 1.725 1.726 1.726 1.727 ... 1.718 1.718 1.718
#     PLAT_SPEED_GR  (time) float64 ...
#     PLAT_COURSE    (time) float64 ...
#     BAT_STATUS     (time) float64 ...
#     U              (time) float64 nan 0.01158 0.01168 ... -5.708e-06 nan
#     V              (time) float64 nan 0.003548 0.003429 ... 5.198e-07 nan
# Attributes: (12/67)
#     title:                               Data from instrument IME-HEREON003 o...
#     institution:                         IMEDEA (Instituto MEDiterráneo de Es...
#     netcdf_version:                      3.0
#     Conventions:                         CF-1.6
#     abstract:                            Deployment of IME-HEREON003 in FaSt-...
#     summary:                             Deployment of IME-HEREON003 in FaSt-...
#     ...                                  ...
#     citation:                            Balearic Island Coastal and Observin...
#     acknowledgement:                     The FaSt-SWOT project is funded by t...
#     update_interval:                     every 3600 seconds
#     DODS.strlen:                         34
#     DODS.dimName:                        name_strlen
#     DODS_EXTRA.Unlimited_Dimension:      time

# %%
outdir_an = "/Users/Gomez023/Library/CloudStorage/OneDrive-UniversitatdelesIllesBalears/FaSt-SWOT/Data/in_situ/analyses/drifters/HEREON/"
# add hereon

# %%
outname
# Out:
# 'drifter_hereon003-ime_hereon003'

# %%
ds_f.to_netcdf(outdir_an + outname + '_inertial_osc_filt' + '.nc')

# %%
# !ls /Users/Gomez023/Library/CloudStorage/OneDrive-UniversitatdelesIllesBalears/FaSt-SWOT/Data/in_situ/analyses/drifters/HEREON/
# Out:
# drifter_hereon003-ime_hereon003_inertial_osc_filt.nc

# %% [markdown]
# # Looking at 4 days of leg 1 campaign:

# %%
ds_s = ds.sel(time=slice("2023-04-26 00:00", "2023-05-02 23:59"))
ds_f_s = ds_f.sel(time=slice("2023-04-26 00:00", "2023-05-02 23:59"))

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.plot(ds_s.U, c='b')
plt.plot(ds_f_s.U, c='r')
plt.title('U [m/s]')
plt.grid()

plt.subplot(1,2,2)
plt.plot(ds_s.V, c='b', label='processed')
plt.plot(ds_f_s.V, c='r', label='proc. + inert. osc. filter')
plt.grid()
plt.title('V [m/s]')
plt.legend(loc=0)
plt.show()
