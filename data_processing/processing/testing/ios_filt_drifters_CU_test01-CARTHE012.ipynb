# %%
# Filtering IOs code by Clement Ubelmann
## adapted to python function by Laura Gómez Navarro

import numpy
import matplotlib.pylab as plt
from datetime import datetime, timedelta
from netCDF4 import Dataset

# %% [markdown]
# # Trying for CARTHE 010 --> as error rises on plot!

# %%
filedir = "/Users/Gomez023/src/git/FaSt-SWOT/data/drifters/L1_IMEDEA/"
infile = filedir + 'drifter_carthe017-ime_carthe012.nc'

# %%
with Dataset(infile, 'r') as fcid:
    time = numpy.array(fcid.variables['time'][1:-1])*60 # seconds (originally in minutes)
    u = numpy.array(fcid.variables['U'][1:-1])
    v = numpy.array(fcid.variables['V'][1:-1])
    lat = numpy.array(fcid.variables['LAT'][1:-1])
    lon = numpy.array(fcid.variables['LON'][1:-1]) # added for plot below
## why ignoring first and last point?

# %%
plt.scatter(lon, lat)
plt.show()

# %%
u.shape
# Out:
# (371,)

# %%
((u.shape[0]) * 10) / 60. # to get hours of drifter traj.
# Out:
# 61.833333333333336

# %%
24*3
# Out:
# 72

# %% [markdown]
# # --> maybe ALSO problem is drifter is less than 3 days long?!

# %%
# Get real and imaginary part:
U = u + 1j*v
U
# Out:
# array([ 0.06742922+0.00792919j,  0.10267772+0.00348886j,
#         0.126618  -0.01064467j,  0.14006131-0.03095614j,
#         0.14682146-0.04901868j,  0.14923356-0.06205732j,
#         0.14815375-0.07065518j,  0.14466335-0.07545091j,
#         0.13854631-0.07987214j,  0.13020259-0.0860193j ,
#         0.1202292 -0.09449146j,  0.11034257-0.10492486j,
#         0.10148891-0.11636447j,  0.09516463-0.12802241j,
#         0.09196831-0.14031484j,  0.09186495-0.15230131j,
#         0.0951166 -0.16361454j,  0.10037174-0.17388088j,
#         0.10625011-0.18317474j,  0.1110381 -0.1912617j ,
#         0.11507124-0.19911214j,  0.11758962-0.2071235j ,
#         0.11914489-0.21534206j,  0.1195857 -0.22372775j,
#         0.11829848-0.23232303j,  0.11510166-0.24165356j,
#         0.10953954-0.25071241j,  0.10131654-0.26209446j,
#         0.09019441-0.2748038j ,  0.07642413-0.28984092j,
#         0.05972286-0.30884663j,  0.04180224-0.33177577j,
#         0.02324599-0.35664514j,  0.00547829-0.3807278j ,
#        -0.01053091-0.40141177j, -0.0257722 -0.41709018j,
#        -0.03959028-0.42709341j, -0.05183185-0.43238268j,
#        -0.06262792-0.43721334j, -0.07208217-0.44074905j,
#        -0.08093322-0.44331333j, -0.09041994-0.44498958j,
#        -0.10114915-0.44473954j, -0.11335207-0.44259539j,
#        -0.12689856-0.43887483j, -0.14111915-0.43383791j,
#        -0.15645083-0.42753339j, -0.17253743-0.41955704j,
#        -0.18952456-0.40949247j, -0.20729581-0.39702487j,
#        -0.22529399-0.38243674j, -0.2424297 -0.36690816j,
#        -0.25839868-0.35164185j, -0.27258403-0.33820239j,
#        -0.2854934 -0.32794009j, -0.29770049-0.3216313j ,
#        -0.31005099-0.31873543j, -0.32338739-0.31744404j,
#        -0.34737111+0.01854273j, -0.35937586+0.01909745j,
#        -0.3695337 +0.02365548j, -0.37686869+0.03243237j,
#        -0.38000594+0.04408652j, -0.37831386+0.05662451j,
#        -0.37063126+0.06722469j, -0.35500943+0.07396822j,
#        -0.33148   +0.07481016j, -0.30236932+0.06856326j,
#        -0.27146421+0.05647362j, -0.24341318+0.04071455j,
#        -0.22190061+0.02398752j, -0.20827944+0.00935231j,
#        -0.20144085-0.00128617j, -0.19846903-0.00780317j,
#        -0.19764454-0.01095296j, -0.19775988-0.01232514j,
#        -0.19778351-0.01260445j, -0.1977837 -0.01260445j,
#        -0.19515554-0.01243695j, -0.18749986-0.01194905j,
#        -0.17100927-0.01089813j, -0.13965388-0.00889989j,
#        -0.09212322-0.00587085j])

# %%
dt = time[1] - time[0]
dt # in seconds, for CARTHE time sampling is 10 mins
# Out:
# 600

# %% [markdown]
# $fc = 2 * 2 * \frac{\pi}{86164} * sin(mean(lat) * \frac{\pi}{180})$

# %%
fc = 2 * 2 * numpy.pi/86164 * numpy.sin(lat.mean() * numpy.pi/180)  # s-1
# earth's rotational period is 86164 s
fc
# Out:
# 9.325296206798465e-05

# %%
time_conv = numpy.arange(-3*86400, 3*86400+dt, dt)
time_conv
# Out:
# array([-259200, -258600, -258000, -257400, -256800, -256200, -255600,
#        -255000, -254400, -253800, -253200, -252600, -252000, -251400,
#        -250800, -250200, -249600, -249000, -248400, -247800, -247200,
#        -246600, -246000, -245400, -244800, -244200, -243600, -243000,
#        -242400, -241800, -241200, -240600, -240000, -239400, -238800,
#        -238200, -237600, -237000, -236400, -235800, -235200, -234600,
#        -234000, -233400, -232800, -232200, -231600, -231000, -230400,
#        -229800, -229200, -228600, -228000, -227400, -226800, -226200,
#        -225600, -225000, -224400, -223800, -223200, -222600, -222000,
#        -221400, -220800, -220200, -219600, -219000, -218400, -217800,
#        -217200, -216600, -216000, -215400, -214800, -214200, -213600,
#        -213000, -212400, -211800, -211200, -210600, -210000, -209400,
#        -208800, -208200, -207600, -207000, -206400, -205800, -205200,
#        -204600, -204000, -203400, -202800, -202200, -201600, -201000,
#        -200400, -199800, -199200, -198600, -198000, -197400, -196800,
#        -196200, -195600, -195000, -194400, -193800, -193200, -192600,
#        -192000, -191400, -190800, -190200, -189600, -189000, -188400,
#        -187800, -187200, -186600, -186000, -185400, -184800, -184200,
#        -183600, -183000, -182400, -181800, -181200, -180600, -180000,
#        -179400, -178800, -178200, -177600, -177000, -176400, -175800,
#        -175200, -174600, -174000, -173400, -172800, -172200, -171600,
#        -171000, -170400, -169800, -169200, -168600, -168000, -167400,
#        -166800, -166200, -165600, -165000, -164400, -163800, -163200,
#        -162600, -162000, -161400, -160800, -160200, -159600, -159000,
#        -158400, -157800, -157200, -156600, -156000, -155400, -154800,
#        -154200, -153600, -153000, -152400, -151800, -151200, -150600,
#        -150000, -149400, -148800, -148200, -147600, -147000, -146400,
#        -145800, -145200, -144600, -144000, -143400, -142800, -142200,
#        -141600, -141000, -140400, -139800, -139200, -138600, -138000,
#        -137400, -136800, -136200, -135600, -135000, -134400, -133800,
#        -133200, -132600, -132000, -131400, -130800, -130200, -129600,
#        -129000, -128400, -127800, -127200, -126600, -126000, -125400,
#        -124800, -124200, -123600, -123000, -122400, -121800, -121200,
#        -120600, -120000, -119400, -118800, -118200, -117600, -117000,
#        -116400, -115800, -115200, -114600, -114000, -113400, -112800,
#        -112200, -111600, -111000, -110400, -109800, -109200, -108600,
#        -108000, -107400, -106800, -106200, -105600, -105000, -104400,
#        -103800, -103200, -102600, -102000, -101400, -100800, -100200,
#         -99600,  -99000,  -98400,  -97800,  -97200,  -96600,  -96000,
#         -95400,  -94800,  -94200,  -93600,  -93000,  -92400,  -91800,
#         -91200,  -90600,  -90000,  -89400,  -88800,  -88200,  -87600,
#         -87000,  -86400,  -85800,  -85200,  -84600,  -84000,  -83400,
#         -82800,  -82200,  -81600,  -81000,  -80400,  -79800,  -79200,
#         -78600,  -78000,  -77400,  -76800,  -76200,  -75600,  -75000,
#         -74400,  -73800,  -73200,  -72600,  -72000,  -71400,  -70800,
#         -70200,  -69600,  -69000,  -68400,  -67800,  -67200,  -66600,
#         -66000,  -65400,  -64800,  -64200,  -63600,  -63000,  -62400,
#         -61800,  -61200,  -60600,  -60000,  -59400,  -58800,  -58200,
#         -57600,  -57000,  -56400,  -55800,  -55200,  -54600,  -54000,
#         -53400,  -52800,  -52200,  -51600,  -51000,  -50400,  -49800,
#         -49200,  -48600,  -48000,  -47400,  -46800,  -46200,  -45600,
#         -45000,  -44400,  -43800,  -43200,  -42600,  -42000,  -41400,
#         -40800,  -40200,  -39600,  -39000,  -38400,  -37800,  -37200,
#         -36600,  -36000,  -35400,  -34800,  -34200,  -33600,  -33000,
#         -32400,  -31800,  -31200,  -30600,  -30000,  -29400,  -28800,
#         -28200,  -27600,  -27000,  -26400,  -25800,  -25200,  -24600,
#         -24000,  -23400,  -22800,  -22200,  -21600,  -21000,  -20400,
#         -19800,  -19200,  -18600,  -18000,  -17400,  -16800,  -16200,
#         -15600,  -15000,  -14400,  -13800,  -13200,  -12600,  -12000,
#         -11400,  -10800,  -10200,   -9600,   -9000,   -8400,   -7800,
#          -7200,   -6600,   -6000,   -5400,   -4800,   -4200,   -3600,
#          -3000,   -2400,   -1800,   -1200,    -600,       0,     600,
#           1200,    1800,    2400,    3000,    3600,    4200,    4800,
#           5400,    6000,    6600,    7200,    7800,    8400,    9000,
#           9600,   10200,   10800,   11400,   12000,   12600,   13200,
#          13800,   14400,   15000,   15600,   16200,   16800,   17400,
#          18000,   18600,   19200,   19800,   20400,   21000,   21600,
#          22200,   22800,   23400,   24000,   24600,   25200,   25800,
#          26400,   27000,   27600,   28200,   28800,   29400,   30000,
#          30600,   31200,   31800,   32400,   33000,   33600,   34200,
#          34800,   35400,   36000,   36600,   37200,   37800,   38400,
#          39000,   39600,   40200,   40800,   41400,   42000,   42600,
#          43200,   43800,   44400,   45000,   45600,   46200,   46800,
#          47400,   48000,   48600,   49200,   49800,   50400,   51000,
#          51600,   52200,   52800,   53400,   54000,   54600,   55200,
#          55800,   56400,   57000,   57600,   58200,   58800,   59400,
#          60000,   60600,   61200,   61800,   62400,   63000,   63600,
#          64200,   64800,   65400,   66000,   66600,   67200,   67800,
#          68400,   69000,   69600,   70200,   70800,   71400,   72000,
#          72600,   73200,   73800,   74400,   75000,   75600,   76200,
#          76800,   77400,   78000,   78600,   79200,   79800,   80400,
#          81000,   81600,   82200,   82800,   83400,   84000,   84600,
#          85200,   85800,   86400,   87000,   87600,   88200,   88800,
#          89400,   90000,   90600,   91200,   91800,   92400,   93000,
#          93600,   94200,   94800,   95400,   96000,   96600,   97200,
#          97800,   98400,   99000,   99600,  100200,  100800,  101400,
#         102000,  102600,  103200,  103800,  104400,  105000,  105600,
#         106200,  106800,  107400,  108000,  108600,  109200,  109800,
#         110400,  111000,  111600,  112200,  112800,  113400,  114000,
#         114600,  115200,  115800,  116400,  117000,  117600,  118200,
#         118800,  119400,  120000,  120600,  121200,  121800,  122400,
#         123000,  123600,  124200,  124800,  125400,  126000,  126600,
#         127200,  127800,  128400,  129000,  129600,  130200,  130800,
#         131400,  132000,  132600,  133200,  133800,  134400,  135000,
#         135600,  136200,  136800,  137400,  138000,  138600,  139200,
#         139800,  140400,  141000,  141600,  142200,  142800,  143400,
#         144000,  144600,  145200,  145800,  146400,  147000,  147600,
#         148200,  148800,  149400,  150000,  150600,  151200,  151800,
#         152400,  153000,  153600,  154200,  154800,  155400,  156000,
#         156600,  157200,  157800,  158400,  159000,  159600,  160200,
#         160800,  161400,  162000,  162600,  163200,  163800,  164400,
#         165000,  165600,  166200,  166800,  167400,  168000,  168600,
#         169200,  169800,  170400,  171000,  171600,  172200,  172800,
#         173400,  174000,  174600,  175200,  175800,  176400,  177000,
#         177600,  178200,  178800,  179400,  180000,  180600,  181200,
#         181800,  182400,  183000,  183600,  184200,  184800,  185400,
#         186000,  186600,  187200,  187800,  188400,  189000,  189600,
#         190200,  190800,  191400,  192000,  192600,  193200,  193800,
#         194400,  195000,  195600,  196200,  196800,  197400,  198000,
#         198600,  199200,  199800,  200400,  201000,  201600,  202200,
#         202800,  203400,  204000,  204600,  205200,  205800,  206400,
#         207000,  207600,  208200,  208800,  209400,  210000,  210600,
#         211200,  211800,  212400,  213000,  213600,  214200,  214800,
#         215400,  216000,  216600,  217200,  217800,  218400,  219000,
#         219600,  220200,  220800,  221400,  222000,  222600,  223200,
#         223800,  224400,  225000,  225600,  226200,  226800,  227400,
#         228000,  228600,  229200,  229800,  230400,  231000,  231600,
#         232200,  232800,  233400,  234000,  234600,  235200,  235800,
#         236400,  237000,  237600,  238200,  238800,  239400,  240000,
#         240600,  241200,  241800,  242400,  243000,  243600,  244200,
#         244800,  245400,  246000,  246600,  247200,  247800,  248400,
#         249000,  249600,  250200,  250800,  251400,  252000,  252600,
#         253200,  253800,  254400,  255000,  255600,  256200,  256800,
#         257400,  258000,  258600,  259200])

# %% [markdown]
# # --> why 3?

# %%
len(time_conv)
# Out:
# 865

# %%
u.shape
# Out:
# (275,)

# %%
len(time)
# Out:
# 275

# %% [markdown]
# $taul = 3 * fc^{-1}$

# %%
taul = 3 * fc**-1
taul
# Out:
# 32170.559877903885

# %% [markdown]
# $gl = exp(-1j * fc * time\_conv) * exp(-taul^{-2} * (time\_conv)^2)$
#
# numpy.exp..
#
# $((\frac{gl^T}{\sum{d}})^T)^T$

# %%
# gl = 
# (numpy.exp(-1j*numpy.outer(fc[:],time_conv))*numpy.exp(-numpy.outer(taul**-2,time_conv**2))).reshape(len(time),len(time_conv))
gl = numpy.exp(-1j * fc * time_conv) * numpy.exp(-taul**-2 * time_conv**2)
gl = (gl.T / numpy.sum(numpy.abs(gl), axis=0).T).T

Unio = numpy.convolve(U, gl, 'same')

u_nio = numpy.real(Unio)
v_nio = numpy.imag(Unio)

# %%
u_nio.shape
# Out:
# (865,)

# %%
plt.figure(figsize=(14,10))
plt.plot(time, u, c='k', label='u total', alpha=0.5)
plt.plot(time, u_nio, c='r', label='u nio', alpha=0.5)
plt.plot(time, u - u_nio, c='b', label='u res', alpha=0.5)
plt.legend()
plt.grid()
plt.show()
# plt.savefig('drifter_laura.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 plt.figure(figsize=(14,10))
#       2 plt.plot(time, u, c='k', label='u total', alpha=0.5)
# ----> 3 plt.plot(time, u_nio, c='r', label='u nio', alpha=0.5)
#       4 plt.plot(time, u - u_nio, c='b', label='u res', alpha=0.5)
#       5 plt.legend()
#
# File /opt/anaconda3/envs/venv_fswot/lib/python3.11/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File /opt/anaconda3/envs/venv_fswot/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File /opt/anaconda3/envs/venv_fswot/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/anaconda3/envs/venv_fswot/lib/python3.11/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (275,) and (865,)

# %%
len(u)
# Out:
# 1898

# %%
len(time)
# Out:
# 1898

# %%
len(u_nio)
# Out:
# 1898
