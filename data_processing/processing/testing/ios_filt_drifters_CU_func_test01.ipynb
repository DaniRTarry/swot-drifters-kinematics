# %%
# Filtering IOs code by Clement Ubelmann
## adapted to python function by Laura Gómez Navarro

import numpy
import matplotlib.pylab as plt
from datetime import datetime, timedelta
from netCDF4 import Dataset

# %%
import sys
sys.path.insert(0, "../../processing/")
from ios_filt_drifters import filt_ios

# %%
filedir = "/Users/Gomez023/src/git/FaSt-SWOT/data/drifters/L1_IMEDEA/"
infile = filedir + 'drifter_carthe007-ime_carthe002.nc'

# %%
ures, vres = filt_ios(infile)

# %% [markdown]
# # Trying the different plotting options:

# %%
ures, vres = filt_ios(infile, plot_output="yes") #, plot_output="no", savefig=None

# %%
ures, vres = filt_ios(infile, savefig='test.png')
# --> works good 
# !rm test.png

# %%
ures, vres = filt_ios(infile, plot_output="yes", savefig='test.png')
# --> works good 
# !rm test.png
