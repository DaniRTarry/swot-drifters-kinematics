# %% [markdown]
# # Processing all HEREON drifters
# ## Have first outputs and corrected trajectories
#
# # Remember!
# ### Need to run base notebook first: fast_swot_drifter_processing_params_testing.ipynb

# %%
import papermill as pm

# %% [markdown]
# # Defining the parameters:

# %%
# Parameters
url_drifter = "drifter_carthe006-ime_carthe001/L0/2023/dep0002_drifter-carthe006_ime-carthe001_L0_2023-04-26.nc?"
# TO L0, 
#url_01 = url_root + "drifter_hereon011-ime_hereon011/L0/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc?"

drifter_type = 'H' # C: CARTHE ; H: Hereon ; S: SVP-B 
# diff_time_thres = 3600*2 # [s] 1h # Will be different for SVP, higher as time res. is 1hr
diff_time_thres = 3600 # [s] 1h # Will be different for SVP, higher as time res. is 1hr

temp_res = 600. # Specifying seconds 
# n_window = 12 # we leave like this for now

# %% [markdown]
# # Leg 1:

# %%
url_drifters = []

#"drifter_carthe006-ime_carthe001/L0/2023/dep0002_drifter-carthe006_ime-carthe001_L0_2023-04-26.nc?"

# %%
#11:
url_01 = "drifter_hereon011-ime_hereon011/L1/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc?" 
print(url_01)
url_drifters.append(url_01)

mm = '4'.zfill(2)

#10: 28/04
drifter_num = '10'.zfill(3)
dd = '28'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
# ds_her010 = xr.open_dataset(url_01)
print(url_01)
url_drifters.append(url_01)

#09: 27/04
drifter_num = '9'.zfill(3)
dd = '27'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#08: 27/04
drifter_num = '8'.zfill(3)
dd = '27'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#07: 27/04
drifter_num = '7'.zfill(3)
dd = '27'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#06: 27/04
drifter_num = '6'.zfill(3)
dd = '27'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#04: 27/04
drifter_num = '4'.zfill(3)
dd = '27'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#03: 26/04
drifter_num = '3'.zfill(3)
dd = '26'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#02: 26/04
drifter_num = '2'.zfill(3)
dd = '26'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#01: 26/04
drifter_num = '1'.zfill(3)
dd = '26'.zfill(2)
# attention! prev trial done, so here dep0001_ is dep0002_
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0002_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)
# Out:
# drifter_hereon011-ime_hereon011/L1/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc?
# drifter_hereon010-ime_hereon010/L0/2023/dep0001_drifter-hereon010_ime-hereon010_L0_2023-04-28.nc?

# %%
url_drifters
# Out:
# ['drifter_hereon011-ime_hereon011/L1/2023/dep0001_drifter-hereon011_ime-hereon011_L1_2023-04-28.nc?',
#  'drifter_hereon010-ime_hereon010/L0/2023/dep0001_drifter-hereon010_ime-hereon010_L0_2023-04-28.nc?',
#  'drifter_hereon009-ime_hereon009/L0/2023/dep0001_drifter-hereon009_ime-hereon009_L0_2023-04-27.nc?',
#  'drifter_hereon008-ime_hereon008/L0/2023/dep0001_drifter-hereon008_ime-hereon008_L0_2023-04-27.nc?',
#  'drifter_hereon007-ime_hereon007/L0/2023/dep0001_drifter-hereon007_ime-hereon007_L0_2023-04-27.nc?',
#  'drifter_hereon006-ime_hereon006/L0/2023/dep0001_drifter-hereon006_ime-hereon006_L0_2023-04-27.nc?',
#  'drifter_hereon004-ime_hereon004/L0/2023/dep0001_drifter-hereon004_ime-hereon004_L0_2023-04-27.nc?',
#  'drifter_hereon003-ime_hereon003/L0/2023/dep0001_drifter-hereon003_ime-hereon003_L0_2023-04-26.nc?',
#  'drifter_hereon002-ime_hereon002/L0/2023/dep0001_drifter-hereon002_ime-hereon002_L0_2023-04-26.nc?',
# ...

# %%
path = '../../../../../FaSt-SWOT/code/data_processing/drifters/processing/'
outdir = 'HEREON_processing/'

# %%
url_drifters[0].split('/')[0]
# Out:
# 'drifter_hereon011-ime_hereon011'

# %%
for url_drifter in  url_drifters: #[5::]
        pm.execute_notebook(path + 'fast_swot_drifter_processing_params_testing_saving_L0_SOCIB.ipynb'
, path + outdir + url_drifter.split('/')[0] + '_saving_L0_SOCIB.ipynb'
, parameters=dict(url_drifter = url_drifter
                  , drifter_type = drifter_type))
# Out:
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# ...

# %% [markdown]
# # Leg 2:

# %%
url_drifters = []

# %%
mm = '5'.zfill(2)

#05: 08/05
drifter_num = '5'.zfill(3)
dd = '8'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#12: 08/05
drifter_num = '12'.zfill(3)
dd = '8'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#13: 08/05
drifter_num = '13'.zfill(3)
dd = '8'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#14: 08/05
drifter_num = '14'.zfill(3)
dd = '8'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#####

#15: 10/05
drifter_num = '15'.zfill(3)
dd = '10'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#16: 10/05
drifter_num = '16'.zfill(3)
dd = '10'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#17: 10/05
drifter_num = '17'.zfill(3)
dd = '10'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?"
url_drifters.append(url_01)

#18: 10/05
drifter_num = '18'.zfill(3)
dd = '10'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

#19: 10/05
drifter_num = '19'.zfill(3)
dd = '10'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L0/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L0_2023-" + mm + "-" + dd + ".nc?" 
# url_02 = 'http://thredds.socib.es/thredds/dodsC/drifter/surface_drifter/drifter_hereon019-ime_hereon019/L1/2023/dep0001_drifter-hereon019_ime-hereon019_L1_2023-05-10.nc?trajectory,time[0:1:314],LAT[0:1:314],QC_LAT[0:1:314],LON[0:1:314],QC_LON[0:1:314],DEPTH,PLAT_SPEED_GR[0:1:314],QC_PLAT_SPEED_GR[0:1:314],PLAT_COURSE[0:1:314],QC_PLAT_COURSE[0:1:314],BAT_STATUS[0:1:314]'
url_drifters.append(url_01)

#20: 10/05
drifter_num = '20'.zfill(3)
dd = '10'.zfill(2)
url_01 = "drifter_hereon" + drifter_num + "-ime_hereon" + drifter_num + "/L1/2023/dep0001_drifter-hereon" + drifter_num + "_ime-hereon" + drifter_num + "_L1_2023-" + mm + "-" + dd + ".nc?" 
url_drifters.append(url_01)

# %%
for url_drifter in  url_drifters: #[5::]
        pm.execute_notebook(path + 'fast_swot_drifter_processing_params_testing_saving_L0_SOCIB.ipynb'
, path + outdir + url_drifter.split('/')[0] + '_saving_L0_SOCIB.ipynb'
, parameters=dict(url_drifter = url_drifter
                  , drifter_type = drifter_type, diff_time_thres = diff_time_thres, temp_res = temp_res))
# Out:
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# ...
